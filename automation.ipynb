# %% [markdown]
# # Start

# %%
#!/usr/bin/env python
# coding: utf-8

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys  # return keys and so on
from selenium.webdriver.chrome.options import Options  # disable notifications
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver import ActionChains
import undetected_chromedriver as uc
from time import sleep
import pyperclip
import random
import requests
from random import randint
import os       
from urllib.parse import urlparse, parse_qs
from contextlib import suppress


# def get_random_quote():
#     url_array = ['https://quote-garden.herokuapp.com/api/v3/quotes?genre=motivational',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=happiness',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=time',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=inspirational',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=success',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=power',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=science',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=patience',
#                 'https://quote-garden.herokuapp.com/api/v3/quotes?genre=friendship']

#     random_url = url_array[randint(0,len(url_array)-1)]
#     print(random_url)
#     try:
#         quote_len_under_500 = False
#         while(not quote_len_under_500):
#             ## making the get request
#             response = requests.get(random_url)
#             if response.status_code == 200:
#                 ## extracting the core data
#                 json_data = response.json()
#                 data = json_data['data']

#                 ## getting the quote from the data
#                 quote = data[0]['quoteText']
# #                 author = data[0]['quoteAuthor']
#                 if len(quote) < 501:
#                     quote_len_under_500 = True
#                     return quote
#                 else:
#                     print('Quote is too long, fetching another one')
#             else:
#                 print("Error while getting quote")
#     except Exception as e:
#         print("Something went wrong! Try Again! Exception was: ", e)




def read_password_file(filepath):
    """
    Read and return the user/password file.
    """
    try:
        with open(filepath, 'r') as fd:
            lines = fd.readlines()
            fd.close()
            return lines
    except IOError:
        raise ValueError("Can't open password file for reading.")





# # Step 01: Chrome Driver Setup

# In[2]:


driver = uc.Chrome(use_subprocess=True)
driver.maximize_window()  # full screen
url = 'https://www.youtube.com/account'
search_page = ''
driver.get(url)

wait = WebDriverWait(driver, 30)  # time in seconds to wait until timeout

# # Step 02: Inputs Setup

username = 'penori.craiova@gmail.com'
password = read_password_file('./.pass')
backup_code = '4185 0442'
channel_name = '@soundsolace' 

search_phrase = 'relaxing sounds'  # what are we searching for?
total_comments = 20  # how many comments should this bot leave?

# %%
comment_array = ["Just for anyone that needed to see this: everything will be ok ❤️🥺", 
                 "✨💕I'm sending out positive vibes to everyone here. 😘❣💕Have a nice day  🙏 ✨", 
                 "Don't know if someone is reading this, but if you are: *You are amazing and beautiful! I believe in you!* ❤️", 
                 "To anybody who’s reading this, I pray that whatever is hurting you or whatever you are constantly stressing about gets better. May the dark thoughts, the overthinking, and the doubt exit your mind right now. May clarity replace confusion. May peace and calmness fill your life. 💜💜", 
                 "Whoever is reading this, Success is not final, failure is not fatal: it is the courage to continue that counts 💜💜", 
                 "Whoever listening to this, may your heart healed from stress and fulfill it with peace. 🌱🌲🌳🌴🌞💕💗", 
                 "I wish people aren’t cruel 💜💜", "We all have come here for peace of mind of whatever it is. Just remember that someone loves you. May peace be with you 💜💜", 
                 "Literally to the 1% who's reading this, God bless you, and may your dreams come true, stay safe and have a wonderful day 💜💜", 
                 "This is Bob. \n 😊 \n 👚 \n 👖 \n 👞 \n He is 0 years old. Every like this comment gets he gets 1 year older. How old will he get?", 
                 "Don't press read more... \n \n \n \n \n You now have good luck, press like to activate! 💜💜💜💜", 
                 "Everyone has a gift. Find your gift...then pursue it to no end; then that will be your destiny. Your an absolute marksman with your words. I really would like to open my unopened gift. I will try till I am no longer. I figure if you can see and feel the gift, you will be able to open it. 💜💜", 
                 "You will face many defeats in life, but never let yourself be defeated 💜💜", 
                 "Twenty years from now you will be more disappointed by the things that you didn't do than by the ones you did do. So, throw off the bowlines, sail away from safe harbor, catch the trade winds in your sails. Explore, Dream, Discover 💜💜", 
                 "Life is a song - sing it. Life is a game - play it. Life is a challenge - meet it. Life is a dream - realize it. Life is a sacrifice - offer it. Life is love - enjoy 💜💜", 
                 "Life is a series of natural and spontaneous changes. Don't resist them; that only creates sorrow. Let reality be reality, let things flow naturally forward in whatever way they like 💜💜", 
                 "When I stand before God at the end of my. life, I would hope that I would not have a single bit of talent left, and could say 'I used everything you gave me' 💜💜", 
                 "Success is to be measured not so much by the position that one has reached in life as by the obstacles which he has overcome while trying to succeed 💜💜", 
                 "What matters in life is not what happens to you but what you remember and how you remember it 💜💜", 
                 "Throughout life people will make you mad, disrespect you and treat you bad. Let God deal with the things they do, cause hate in your heart will consume you too 💜💜", 
                 "Sometimes you've got to let everything go - purge yourself. If you are unhappy with anything... whatever is bringing you down, get rid of it. Because you'll find that when you're free, your true creativity, your true self comes out 💜💜", 
                 "We are what our thoughts have made us; so take care about what you think. Words are secondary. Thoughts live; they travel far 💜💜", 
                 "Thousands of candles can be lighted from a single candle, and the life of the candle will not be shortened. Happiness never decreases by being shared 💜💜", 
                 "Presence is when you’re no longer waiting for the next moment, believing that the next moment will be more fulfilling than this one 💜💜", 
                 "Life’s meaning is not in following someone else, it is in the unfolding of one’s own self. It is not a process of becoming like someone else, it is to be oneself 💜💜", 
                 "You have to grow from the inside out. None can teach you; none can make you spiritual. There is no other teacher but your own soul 💜💜", 
                 "Don’t let others tell you what you can’t do. Don’t let the limitations of others limit your vision. If you can remove your self-doubt and believe in yourself, you can achieve what you never thought possible 💜💜💜💜", 
                 "Whenever you want to achieve something, keep your eyes open, concentrate and make sure you know exactly what it is you want. No one can hit their target with their eyes closed 💜💜", 
                 "Those who improve with age embrace the power of personal growth and personal achievement and begin to replace youth with wisdom, innocence with understanding, and lack of purpose with self-actualization 💜💜", 
                 "Property may be destroyed and money may lose its purchasing power but, character, health, knowledge and good judgement will always be in demand under all conditions 💜💜"] 

comment = comment_array[randint(0,len(comment_array)-1)]

print(comment)
# Out:
# We are what our thoughts have made us; so take care about what you think. Words are secondary. Thoughts live; they travel far 💜💜

# %%
def accept_conditions():
    accept_all_conditions_01 = driver.find_element(By.XPATH,
                                                   '//span[text()="Accept all"]')
    if accept_all_conditions_01:
        accept_all_conditions_01.click()
    sleep(2)    


def sign_in():
    sign_in_input_form = driver.find_element(By.XPATH, '//*[@id="identifierId"]')
    sign_in_input_form.send_keys(username)

    next_button = driver.find_element(By.XPATH, '//span[text()="Next"]')
    next_button.click()
    

    password_input_field = wait.until(EC.visibility_of_element_located((By.XPATH, '//input[@type="password"]')))
    password_input_field.send_keys(password)

    # passwordNext > div > button

    next_button = driver.find_element(By.XPATH, '//span[text()="Next"]')
    next_button.click()

    sleep(7)


def search_youtube():
    url = 'https://www.youtube.com/'
    driver.get(url)

    # search_field = wait.until(EC.visibility_of_element_located((By.CSS_SELECTOR, '#search')))
    search_field = driver.find_element(By.XPATH, '//input[@id="search"]')
    search_field.click()
    for letter in search_phrase:
        search_field.send_keys(letter)
        wait_time = random.randint(0, 250) / 1000
        sleep(wait_time)

    # search_field.click()
    search_field.send_keys(Keys.RETURN)
    


def select_filters():
    # click on filters
    filters = wait.until(EC.visibility_of_element_located((By.XPATH, '//button[@aria-label="Search filters"]')))
    filters.click()

    # choose from this week
#     this_week = wait.until(EC.visibility_of_element_located((By.XPATH,
#                                                              '/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div[2]/div/ytd-section-list-renderer/div[1]/div[2]/ytd-search-sub-menu-renderer/div[1]/iron-collapse/div/ytd-search-filter-group-renderer[1]/ytd-search-filter-renderer[3]/a/div/yt-formatted-string')))
#     this_week.click()
    
    today = wait.until(EC.visibility_of_element_located((By.XPATH,
                                                             '//yt-formatted-string[text()="Today"]')))
    today.click()
    
    # get the current url
    return driver.current_url  # returns the current search url
    print(search_page)


def fetch_videos(loop_length):
    def fetching_loop(loop_length):
        while loop_length > 0:
            driver.execute_script(
                'window.scrollTo(0, document.documentElement.scrollHeight)')
            sleep(2)
            loop_length -= 1

    fetching_loop(loop_length)  # this defines how many times it scrolls down to fetch more videos

    wait.until(EC.visibility_of_any_elements_located((By.CSS_SELECTOR, 'ytd-video-renderer')))
    return driver.find_elements(By.CSS_SELECTOR, 'ytd-video-renderer')  # list all videos


def find_comment_section():
    # ActionChains(driver).key_down(Keys.END).key_up(Keys.END).perform()
    driver.execute_script(
        'window.scrollTo(0, document.documentElement.scrollHeight / 4)')  # scroll down to comment section, if this does not work, it will keep on scrolling down

    print('should of went down now a bit')

    comments_found = False
    
    sleep(3)

    try:
        driver.find_elements(By.CSS_SELECTOR, '#placeholder-area')
        comments_found = True
    except:
        comments_found = False

    if not comments_found:
        print("initial height scan not enough, proceeding back to top and slowly down by 100px...")
        driver.execute_script('window.scrollTo(0, 0)')
        while True:
            try:
                driver.find_elements(By.CSS_SELECTOR, '#placeholder-area')
                break
            except:
                print('not quite at the comment section, scrolling down a little bit more...')
                driver.execute_script('window.scrollBy(0, 100)')  # scroll down to comment section
                sleep(0.5)
    page_source_text = driver.execute_script('return document.body.innerHTML;')
    if ('Comments are turned off' in page_source_text):
        return False  # comment section found? NO, FALSE
    else:
        print("Comment section has been found.")
        return True


def duplicate_comments_found():  # returns true if duplicates found
    sleep(2)  # wait until the comments appear
    all_comments = driver.find_element(By.CSS_SELECTOR, '#comments').get_attribute('innerHTML')
    own_comments_counter = all_comments.count(channel_name)  # apare de două ori când nu e niciun comment
    print('comment found: ', own_comments_counter)

    return own_comments_counter > 1

def write_comment():
    # add comment
    wait.until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR, '#placeholder-area')))
    comment_box = driver.find_element(By.CSS_SELECTOR, '#placeholder-area')
    comment_box.click()
    print('clicked textbox')

    comment_box = driver.find_element(By.CSS_SELECTOR, '#contenteditable-root')
    print('writing to textbox...')
    #             for letter in comment:  # in case you do not have emojis, but we do have them
    #                 comment_box.send_keys(letter)
    #                 wait_time = random.randint(0, 1000) / 1000
    #                 sleep(wait_time)

    pyperclip.copy(comment)
    sleep(1)
    ActionChains(driver).key_down(Keys.CONTROL).send_keys('v').key_up(Keys.CONTROL).perform()

    print('pasted comment, now waiting 1 second...')

    sleep(1)
    comment_box_submit = driver.find_element(By.CSS_SELECTOR,
                                             '#submit-button > yt-button-shape > button')
    comment_box_submit.click()
    print('finished writing to textbox, now going back one page after 3 seconds...')
    sleep(3)


def is_a_yt_shorts(url):
    if 'shorts' in url:
        return True
    else:
        return False
    
def is_video_in_file(video_link):
    with open('./visited_links.txt', 'r') as file:
        # read all content of a file
        content = file.read()
        # check if string present in a file
        if video_link in content:
            return True
        else:
            return False


# noinspection PyTypeChecker
def get_yt_id(url, ignore_playlist=False):  # this returns just the id of the video, no www's
    # Examples:
    # - http://youtu.be/SA2iWivDJiE
    # - http://www.youtube.com/watch?v=_oPAwA_Udwc&feature=feedu
    # - http://www.youtube.com/embed/SA2iWivDJiE
    # - http://www.youtube.com/v/SA2iWivDJiE?version=3&amp;hl=en_US
    query = urlparse(url)
    if query.hostname == 'youtu.be': return query.path[1:]
    if query.hostname in {'www.youtube.com', 'youtube.com', 'music.youtube.com'}:
        if not ignore_playlist:
        # use case: get playlist id not current video in playlist
            with suppress(KeyError):
                return parse_qs(query.query)['list'][0]
        if query.path == '/watch': return parse_qs(query.query)['v'][0]
        if query.path[:7] == '/watch/': return query.path.split('/')[1]
        if query.path[:7] == '/embed/': return query.path.split('/')[2]
        if query.path[:3] == '/v/': return query.path.split('/')[2]
   # returns None for invalid YouTube url


        


def file_too_large_updater(path):
    if os.path.getsize(path) > (10 * 1024 * 1024):  # bigger than 10MB, dimension is given in Bytes
        os.remove(path)
        with open(path, 'w') as f:  # this makes a new file
            f.write('Create a new text file!')
        print("anewtextfilewascreated")
    else:
        print('nothing happened with file too large updater')

        
def post_comments(total_commentsl: int, comment: str, loop_length: int):
    videos = fetch_videos(loop_length)
    comments_counter = 0
    vid_counter = 0

    print(f'videos have length of {len(videos)}')



            
    # save all videos to text file, if they are not a yt shorts
    for i in range(1, len(videos)+1): 
        try:
            video_views = videos[i-1].find_element(By.CSS_SELECTOR,'#metadata-line > span').get_attribute("innerHTML")
            print(video_views) 
        except Exception as e:
            print("____we are not appending this video number", i)
            print('there is no meta for views, we will continue with next video', 'exception was: ', e)
            continue
        else:  # this gets executed if the try is successful
            if 'views' in video_views:  # check if the word is in there, 1K views denotes a video, all else is a live or playlist
                print('views' in video_views, "is true, the value is", video_views)
                # go to video and do shit
                print('saving video to file...')
                
                
                xpath_string = '(//a[@id="video-title"])[' + str(i) + ']'
                href = videos[i-1].find_element(By.XPATH, xpath_string)
                print(href.get_attribute('href'))
                href = href.get_attribute('href')
                with open('./fetched_videos.txt', 'a') as f:  # this overwrites file and starts it from scratch
                    f.write(href + '\n')  # also puts a new line
            else: 
                print('word views not found, continuing to next file')
                continue
    print("wrote video links to visited_links.txt file")

    # read contents of fetched videos and sanve them to variable        
    with open("fetched_videos.txt", 'r+') as fp:  # r+ is for truncation
        # read an store all lines into list
        lines = fp.readlines()        
#         f.truncate(0) # need '0' when using r+, 
    open('file.txt', 'w').close()  # this deletes the file contents

    for line in lines:  # go through each line of fetched videos file
        print(line)
        line = line.replace(" ", "")
        if line == "":
            print('empty line')
            continue
        else:
            print("not empty line")
        if is_a_yt_shorts(line):
            continue
        else:
            video_id = get_yt_id(line)
            if is_video_in_file(video_id):
                continue
            else:  
                if comments_counter == total_comments:
                    print(f'We reached {total_comments} comments. Stopping script. Goodbye!')
                    break
                    
                # writes link to file
                visited_links_path = "./visited_links.txt"
                with open(visited_links_path, 'a') as f:
                    f.write(video_id + '\n')  # also puts a new line
                    print("wrote video link to txt file")
                file_too_large_updater(visited_links_path)  # check if file got too large, to avoid filling up of memory
                # post comment here...
                vid_counter += 1
                print(f'comments counter is {comments_counter}')
                print(f'vid counter is: {vid_counter}')
                print('videocacat________________________')
                

                print('going to video...')




                main_video_list_window = driver.current_window_handle
#                 video = videos[i].find_element(By.CSS_SELECTOR, '#video-title')
                video_link = line
                print('link for video is:', video_link)

#                 if is_a_yt_shorts(video_link):
#                     print("This video already is a YT shorts, skipping it with continue...")
#                     continue
#                 print('this video is not a yt shorts')
#                 video_id = get_yt_id(video_link)

#                 if is_video_in_file(video_id):
#                     print('we already visited this video, lets continue with the next one')
#                     continue  # we already visited this vid, sorry
#                 else:
                    # write video to file
#                 print('video not visited, write to file')
#                 visited_links_path = './visited_links.txt'
#                 with open(visited_links_path, 'a') as f:
#                     f.write(video_id + '\n')  # also puts a new line
#                     print("wrote video link to txt file")


                driver.switch_to.new_window('tab')
                driver.get(video_link)
                print('___opened video in new tab')


                sleep(2)  # wait a bit until the page fully loads


                if(find_comment_section() == False):
#                     driver.execute_script('window.history.go(-1)')
                    driver.close()   
                    driver.switch_to.window(main_video_list_window)
                    print("This video has comment section disabled, going back...")
                    continue


                if duplicate_comments_found():
#                     driver.execute_script('window.history.go(-1)')
                    driver.close()
                    driver.switch_to.window(main_video_list_window)
                    print("This video already has a comment on it! Going back...")
                    continue
                else:
                    wait.until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR, '#title > h1')))
                    print('found the title :), page is loaded')
                    # do main shit
                    write_comment()
                    comments_counter += 1
                    driver.close()
                    driver.switch_to.window(main_video_list_window)
    if comments_counter != total_comments:
        print('comments counter is not reached, we are increasing loop length')
        post_comments(total_comments - comments_counter, comment, loop_length + 5) 

    






# #     for video in videos:
#     for i in range(0, len(videos)):

        


#         print(videos[i].get_attribute('innerHTML'))

# %%
# # Step 03: accept terms and rights
accept_conditions()

# %%
# # Step 04: Sign in
sign_in()

# %%
# Step 05: Search
# wait for search button to appear, you need to tap yes on phone before this...

search_youtube()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In [158], line 4
#       1 # Step 05: Search
#       2 # wait for search button to appear, you need to tap yes on phone before this...
# ----> 4 search_youtube()
#
# Cell In [155], line 30, in search_youtube()
#      28 def search_youtube():
#      29     url = 'https://www.youtube.com/'
# ---> 30     driver.get(url)
#      32     # search_field = wait.until(EC.visibility_of_element_located((By.CSS_SELECTOR, '#search')))
#      33     search_field = driver.find_element(By.XPATH, '//input[@id="search"]')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\undetected_chromedriver\__init__.py:541, in Chrome.get(self, url)
#     540 def get(self, url):
# --> 541     if self._get_cdc_props():
#     542         self._hook_remove_cdc_props()
#     543     return super().get(url)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\undetected_chromedriver\__init__.py:513, in Chrome._get_cdc_props(self)
#     512 def _get_cdc_props(self):
# --> 513     return self.execute_script(
#     514         """
#     515         let objectToInspect = window,
#     516             result = [];
#     517         while(objectToInspect !== null)
#     518         { result = result.concat(Object.getOwnPropertyNames(objectToInspect));
#     519           objectToInspect = Object.getPrototypeOf(objectToInspect); }
#     520         return result.filter(i => i.match(/.+_.+_(Array|Promise|Symbol)/ig))
#     521         """
#     522     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\webdriver.py:492, in WebDriver.execute_script(self, script, *args)
#     489 converted_args = list(args)
#     490 command = Command.W3C_EXECUTE_SCRIPT
# --> 492 return self.execute(command, {
#     493     'script': script,
#     494     'args': converted_args})['value']
#
# File ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File ~\AppData\Roaming\Python\Python38\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=108.0.5359.72)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00F8F243]
# 	(No symbol) [0x00F17FD1]
# 	(No symbol) [0x00E0D04D]
# 	(No symbol) [0x00DF2D7A]
# 	(No symbol) [0x00E5BE7B]
# 	(No symbol) [0x00E6C196]
# 	(No symbol) [0x00E58386]
# 	(No symbol) [0x00E3163C]
# 	(No symbol) [0x00E3269D]
# 	GetHandleVerifier [0x01229A22+2655074]
# 	GetHandleVerifier [0x0121CA24+2601828]
# 	GetHandleVerifier [0x01038C0A+619850]
# 	GetHandleVerifier [0x01037830+614768]
# 	(No symbol) [0x00F205FC]
# 	(No symbol) [0x00F25968]
# 	(No symbol) [0x00F25A55]
# 	(No symbol) [0x00F3051B]
# 	BaseThreadInitThunk [0x757AFEF9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77097BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77097B8E+238]

# %%
search_page = select_filters()

# %%
driver.switch_to.window(driver.window_handles[0])

# %%
videos = fetch_videos(1)
print(videos[1])
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8bae44dbde55d51a7ed86cbb00ced165", element="13c7e76e-9604-47f0-8b29-a1f76f70bdd9")>

# %%
print('some text asdfas                 asfd afs adfs asfda                     '.replace(" ", "")) 

line = "somemme ma                afsdf asdf                        "
line = "                        "
# Out:
# sometextasdfasasfdafsadfsasfda
# empty line

# %%
total_comments = 20
post_comments(total_comments, comment, 0)
# Out:
# videos have length of 20
# 4.4K watching
# word views not found, continuing to next file
# 1.9K watching
# word views not found, continuing to next file
# 5.3K watching
# word views not found, continuing to next file
# 1K watching
# word views not found, continuing to next file
# 536 watching
# word views not found, continuing to next file
# 724 watching
# word views not found, continuing to next file
# 22K views
# True is true, the value is 22K views
# saving video to file...
# https://www.youtube.com/watch?v=-NljKEbEEZ8
# 6.8K views
# True is true, the value is 6.8K views
# saving video to file...
# https://www.youtube.com/watch?v=l_NQ2ZFE_sw
# 13K views
# True is true, the value is 13K views
# saving video to file...
# https://www.youtube.com/watch?v=HphvCslECxs
# 3.1K views
# True is true, the value is 3.1K views
# saving video to file...
# https://www.youtube.com/watch?v=twvgHVlus6c
# 23K views
# True is true, the value is 23K views
# saving video to file...
# https://www.youtube.com/watch?v=4LsR637gWVo
# 2.9K views
# True is true, the value is 2.9K views
# saving video to file...
# https://www.youtube.com/watch?v=WN1C4_SciYI
# 9K watching
# word views not found, continuing to next file
# 12K views
# True is true, the value is 12K views
# saving video to file...
# https://www.youtube.com/watch?v=3PXUO_7Pj5o
# 70K views
# True is true, the value is 70K views
# saving video to file...
# https://www.youtube.com/watch?v=TzQW1eQr82E
# 1.8K views
# True is true, the value is 1.8K views
# saving video to file...
# https://www.youtube.com/watch?v=e__OqNA0zhw
# 534 views
# True is true, the value is 534 views
# saving video to file...
# https://www.youtube.com/watch?v=oky3D0-JdsQ
# 93 watching
# word views not found, continuing to next file
# 270 views
# True is true, the value is 270 views
# saving video to file...
# https://www.youtube.com/watch?v=LqqHWJiYZro
# 21K views
# True is true, the value is 21K views
# saving video to file...
# https://www.youtube.com/watch?v=NuT0BbzeJ38
# wrote video links to visited_links.txt file
# https://www.youtube.com/watch?v=-NljKEbEEZ8
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 0
# vid counter is: 1
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=-NljKEbEEZ8
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=l_NQ2ZFE_sw
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 1
# vid counter is: 2
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=l_NQ2ZFE_sw
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=HphvCslECxs
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 2
# vid counter is: 3
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=HphvCslECxs
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=twvgHVlus6c
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 3
# vid counter is: 4
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=twvgHVlus6c
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=4LsR637gWVo
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 4
# vid counter is: 5
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=4LsR637gWVo
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=WN1C4_SciYI
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 5
# vid counter is: 6
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=WN1C4_SciYI
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=3PXUO_7Pj5o
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 6
# vid counter is: 7
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=3PXUO_7Pj5o
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=TzQW1eQr82E
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 7
# vid counter is: 8
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=TzQW1eQr82E
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=e__OqNA0zhw
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 8
# vid counter is: 9
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=e__OqNA0zhw
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=oky3D0-JdsQ
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 9
# vid counter is: 10
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=oky3D0-JdsQ
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=LqqHWJiYZro
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 10
# vid counter is: 11
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=LqqHWJiYZro
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=NuT0BbzeJ38
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 11
# vid counter is: 12
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=NuT0BbzeJ38
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# comments counter is not reached, we are increasing loop length
# videos have length of 116
# 4.4K watching
# word views not found, continuing to next file
# 1.9K watching
# word views not found, continuing to next file
# 5.3K watching
# word views not found, continuing to next file
# 1K watching
# word views not found, continuing to next file
# 536 watching
# word views not found, continuing to next file
# 724 watching
# word views not found, continuing to next file
# 22K views
# True is true, the value is 22K views
# saving video to file...
# https://www.youtube.com/watch?v=-NljKEbEEZ8
# 6.8K views
# True is true, the value is 6.8K views
# saving video to file...
# https://www.youtube.com/watch?v=l_NQ2ZFE_sw
# 13K views
# True is true, the value is 13K views
# saving video to file...
# https://www.youtube.com/watch?v=HphvCslECxs
# 3.1K views
# True is true, the value is 3.1K views
# saving video to file...
# https://www.youtube.com/watch?v=twvgHVlus6c
# 23K views
# True is true, the value is 23K views
# saving video to file...
# https://www.youtube.com/watch?v=4LsR637gWVo
# 2.9K views
# True is true, the value is 2.9K views
# saving video to file...
# https://www.youtube.com/watch?v=WN1C4_SciYI
# 9K watching
# word views not found, continuing to next file
# 12K views
# True is true, the value is 12K views
# saving video to file...
# https://www.youtube.com/watch?v=3PXUO_7Pj5o
# 70K views
# True is true, the value is 70K views
# saving video to file...
# https://www.youtube.com/watch?v=TzQW1eQr82E
# 1.8K views
# True is true, the value is 1.8K views
# saving video to file...
# https://www.youtube.com/watch?v=e__OqNA0zhw
# 534 views
# True is true, the value is 534 views
# saving video to file...
# https://www.youtube.com/watch?v=oky3D0-JdsQ
# 93 watching
# word views not found, continuing to next file
# 270 views
# True is true, the value is 270 views
# saving video to file...
# https://www.youtube.com/watch?v=LqqHWJiYZro
# 21K views
# True is true, the value is 21K views
# saving video to file...
# https://www.youtube.com/watch?v=NuT0BbzeJ38
# 249 watching
# word views not found, continuing to next file
# 9.8K views
# True is true, the value is 9.8K views
# saving video to file...
# https://www.youtube.com/watch?v=7Hc8yzzkloc
# 11K views
# True is true, the value is 11K views
# saving video to file...
# https://www.youtube.com/watch?v=FjQ1FSTsE6A
# 48K views
# True is true, the value is 48K views
# saving video to file...
# https://www.youtube.com/watch?v=JepJ_jyzUV8
# 14K views
# True is true, the value is 14K views
# saving video to file...
# https://www.youtube.com/watch?v=M0HaYAA_M80
# 1.1K watching
# word views not found, continuing to next file
# 4.3K views
# True is true, the value is 4.3K views
# saving video to file...
# https://www.youtube.com/watch?v=GwOSDSjJlnA
# 1.1K views
# True is true, the value is 1.1K views
# saving video to file...
# https://www.youtube.com/watch?v=uu9VQNXoNRk
# 155 watching
# word views not found, continuing to next file
# 7.1K views
# True is true, the value is 7.1K views
# saving video to file...
# https://www.youtube.com/watch?v=z1aCn-8OGrk
# 1.3K views
# True is true, the value is 1.3K views
# saving video to file...
# https://www.youtube.com/watch?v=Z0iME4eTAEY
# 24K views
# True is true, the value is 24K views
# saving video to file...
# https://www.youtube.com/watch?v=CMORghwqwwc
# 498 views
# True is true, the value is 498 views
# saving video to file...
# https://www.youtube.com/watch?v=vWojD9OiG38
# 2 views
# True is true, the value is 2 views
# saving video to file...
# https://www.youtube.com/watch?v=bKZPKNPtNh4
# 7.2K views
# True is true, the value is 7.2K views
# saving video to file...
# https://www.youtube.com/shorts/05HfVCu09PQ
# 181 views
# True is true, the value is 181 views
# saving video to file...
# https://www.youtube.com/watch?v=xmkr9pB1Bag
# 1.1K views
# True is true, the value is 1.1K views
# saving video to file...
# https://www.youtube.com/watch?v=sKxzLS1FaXQ
# 43K views
# True is true, the value is 43K views
# saving video to file...
# https://www.youtube.com/watch?v=wQiO0xJWlOo
# 16K views
# True is true, the value is 16K views
# saving video to file...
# https://www.youtube.com/watch?v=E4zhCTAw5bc
# 259 views
# True is true, the value is 259 views
# saving video to file...
# https://www.youtube.com/watch?v=rNP6NiW0d3w
# 156 watching
# word views not found, continuing to next file
# 856 views
# True is true, the value is 856 views
# saving video to file...
# https://www.youtube.com/shorts/oYcG8kBQKMg
# 1.5K views
# True is true, the value is 1.5K views
# saving video to file...
# https://www.youtube.com/watch?v=bqe3wsv9MxE
# 20 watching
# word views not found, continuing to next file
# 3.2K views
# True is true, the value is 3.2K views
# saving video to file...
# https://www.youtube.com/shorts/CDYdN8wEmt8
# 612 views
# True is true, the value is 612 views
# saving video to file...
# https://www.youtube.com/watch?v=NXFzMGJSP6w
# 229 views
# True is true, the value is 229 views
# saving video to file...
# https://www.youtube.com/watch?v=NNpVC121HEg
# 3.9K views
# True is true, the value is 3.9K views
# saving video to file...
# https://www.youtube.com/watch?v=8qRQR2u7KCM
# 2.7K views
# True is true, the value is 2.7K views
# saving video to file...
# https://www.youtube.com/watch?v=oQoUys2aduE
# 1.1K views
# True is true, the value is 1.1K views
# saving video to file...
# https://www.youtube.com/watch?v=i0PGQOWpcdE
# 571 views
# True is true, the value is 571 views
# saving video to file...
# https://www.youtube.com/watch?v=MZSLfRnwcSs
# 13 views
# True is true, the value is 13 views
# saving video to file...
# https://www.youtube.com/watch?v=cPqLUPcZ8dk
# 2.2K views
# True is true, the value is 2.2K views
# saving video to file...
# https://www.youtube.com/watch?v=q7tYux9Z9jg
# 149 views
# True is true, the value is 149 views
# saving video to file...
# https://www.youtube.com/watch?v=H_d_kqn9K-0
# 665 views
# True is true, the value is 665 views
# saving video to file...
# https://www.youtube.com/watch?v=phxSXOap9vw
# 1.4K views
# True is true, the value is 1.4K views
# saving video to file...
# https://www.youtube.com/watch?v=RFNsW6JUOrg
# 1K views
# True is true, the value is 1K views
# saving video to file...
# https://www.youtube.com/watch?v=mflf9exB1h0
# ____we are not appending this video number 58
# there is no meta for views, we will continue with next video exception was:  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#metadata-line > span"}
#   (Session info: chrome=108.0.5359.72)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00F8F243]
# 	(No symbol) [0x00F17FD1]
# 	(No symbol) [0x00E0D04D]
# 	(No symbol) [0x00E3C0B0]
# 	(No symbol) [0x00E3C22B]
# 	(No symbol) [0x00E32CA1]
# 	(No symbol) [0x00E585D4]
# 	(No symbol) [0x00E32BFF]
# 	(No symbol) [0x00E58804]
# 	(No symbol) [0x00E6C9EB]
# 	(No symbol) [0x00E58386]
# 	(No symbol) [0x00E3163C]
# 	(No symbol) [0x00E3269D]
# 	GetHandleVerifier [0x01229A22+2655074]
# 	GetHandleVerifier [0x0121CA24+2601828]
# 	GetHandleVerifier [0x01038C0A+619850]
# 	GetHandleVerifier [0x01037830+614768]
# 	(No symbol) [0x00F205FC]
# 	(No symbol) [0x00F25968]
# 	(No symbol) [0x00F25A55]
# 	(No symbol) [0x00F3051B]
# 	BaseThreadInitThunk [0x757AFEF9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77097BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77097B8E+238]
#
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=X-enRn6ESRM
# 3 views
# True is true, the value is 3 views
# saving video to file...
# https://www.youtube.com/watch?v=VvXjpqPmDeU
# 5.2K views
# True is true, the value is 5.2K views
# saving video to file...
# https://www.youtube.com/watch?v=XNVbGdUqazY
# 10K views
# True is true, the value is 10K views
# saving video to file...
# https://www.youtube.com/watch?v=IShIjg71li4
# 374 views
# True is true, the value is 374 views
# saving video to file...
# https://www.youtube.com/shorts/hLKf06n0Rsg
# 160 views
# True is true, the value is 160 views
# saving video to file...
# https://www.youtube.com/watch?v=ROapoRXpLoI
# 1.7K views
# True is true, the value is 1.7K views
# saving video to file...
# https://www.youtube.com/watch?v=mqVR2pcwMf8
# 1.6K views
# True is true, the value is 1.6K views
# saving video to file...
# https://www.youtube.com/watch?v=xNVooDg4jBg
# 1 view
# word views not found, continuing to next file
# 47 views
# True is true, the value is 47 views
# saving video to file...
# https://www.youtube.com/watch?v=gJOPoo32_i4
# 72 views
# True is true, the value is 72 views
# saving video to file...
# https://www.youtube.com/watch?v=YbjPTgHXPbY
# 1.6K views
# True is true, the value is 1.6K views
# saving video to file...
# https://www.youtube.com/watch?v=Y9PN3tJh5CU
# 799 views
# True is true, the value is 799 views
# saving video to file...
# https://www.youtube.com/watch?v=6gTw8LqSHkA
# 6 views
# True is true, the value is 6 views
# saving video to file...
# https://www.youtube.com/watch?v=sOzVmZOZfKM
# 1.6K views
# True is true, the value is 1.6K views
# saving video to file...
# https://www.youtube.com/watch?v=hV-PWS1TpU8
# 6.6K views
# True is true, the value is 6.6K views
# saving video to file...
# https://www.youtube.com/watch?v=Zd5Pwm9Hd7s
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=C4HjhKzblKs
# 93 views
# True is true, the value is 93 views
# saving video to file...
# https://www.youtube.com/watch?v=zAzdPsWsPX0
# 353 views
# True is true, the value is 353 views
# saving video to file...
# https://www.youtube.com/watch?v=LluRTysDuq4
# 31 views
# True is true, the value is 31 views
# saving video to file...
# https://www.youtube.com/shorts/dM7ccEnE7_Q
# 1.2K views
# True is true, the value is 1.2K views
# saving video to file...
# https://www.youtube.com/watch?v=RWMpPRMq9n4
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=1nvu1MA_mq8
# 5.1K views
# True is true, the value is 5.1K views
# saving video to file...
# https://www.youtube.com/watch?v=b2mje1EHdIk
# 286 views
# True is true, the value is 286 views
# saving video to file...
# https://www.youtube.com/watch?v=8JkQEpPe2hk
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=DH1DN6SH8bI
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/shorts/ZrvG0EHfFLs
# 1.3K views
# True is true, the value is 1.3K views
# saving video to file...
# https://www.youtube.com/watch?v=RI84R6fdmug
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=LnUpo_IHonE
# 5 watching
# word views not found, continuing to next file
# 505 watching
# word views not found, continuing to next file
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=ScBPL-XLy68
# 20 views
# True is true, the value is 20 views
# saving video to file...
# https://www.youtube.com/watch?v=MF9bSwi89nw
# 2.2K views
# True is true, the value is 2.2K views
# saving video to file...
# https://www.youtube.com/shorts/-4BalfIcR9U
# 542 views
# True is true, the value is 542 views
# saving video to file...
# https://www.youtube.com/shorts/F3N5eW9ehA0
# 1.3K views
# True is true, the value is 1.3K views
# saving video to file...
# https://www.youtube.com/shorts/vIpByUJwe74
# 1.6K views
# True is true, the value is 1.6K views
# saving video to file...
# https://www.youtube.com/shorts/dWylVMmSuvg
# 12K views
# True is true, the value is 12K views
# saving video to file...
# https://www.youtube.com/watch?v=xqeMSNCblJU
# 3 views
# True is true, the value is 3 views
# saving video to file...
# https://www.youtube.com/watch?v=PTm7zF9qBDM
# 525 views
# True is true, the value is 525 views
# saving video to file...
# https://www.youtube.com/shorts/GbsaIUe5Luk
# 74 views
# True is true, the value is 74 views
# saving video to file...
# https://www.youtube.com/watch?v=MNWxdwb_j94
# 172 views
# True is true, the value is 172 views
# saving video to file...
# https://www.youtube.com/shorts/PjS37FUsTIo
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/shorts/maTz6ymMBNs
# 2 views
# True is true, the value is 2 views
# saving video to file...
# https://www.youtube.com/watch?v=Em1x6Xgkwno
# 3 views
# True is true, the value is 3 views
# saving video to file...
# https://www.youtube.com/watch?v=v-Osqu-mz5Y
# 90 views
# True is true, the value is 90 views
# saving video to file...
# https://www.youtube.com/shorts/Yjf0fyTIy9Y
# 2.5K views
# True is true, the value is 2.5K views
# saving video to file...
# https://www.youtube.com/watch?v=F7TMGGGNZxI
# 125 views
# True is true, the value is 125 views
# saving video to file...
# https://www.youtube.com/watch?v=43dQcY-Y6Bo
# 77 views
# True is true, the value is 77 views
# saving video to file...
# https://www.youtube.com/shorts/QA3InmraB6E
# 12 views
# True is true, the value is 12 views
# saving video to file...
# https://www.youtube.com/watch?v=3G6KFa4PYcU
# 163 views
# True is true, the value is 163 views
# saving video to file...
# https://www.youtube.com/watch?v=T07JXnFcKow
# 107 views
# True is true, the value is 107 views
# saving video to file...
# https://www.youtube.com/shorts/73l_lH-2Bfc
# 5 views
# True is true, the value is 5 views
# saving video to file...
# https://www.youtube.com/watch?v=fIcBHTmJRVo
# No views
# True is true, the value is No views
# saving video to file...
# https://www.youtube.com/watch?v=yuIFzh-5Czg
# 101 views
# True is true, the value is 101 views
# saving video to file...
# https://www.youtube.com/watch?v=DIjrLC87wKw
# 624 views
# True is true, the value is 624 views
# saving video to file...
# https://www.youtube.com/watch?v=_c0Eb2Ioo6Y
# 577 views
# True is true, the value is 577 views
# saving video to file...
# https://www.youtube.com/watch?v=kEBdl_kg4Fk
# 885 views
# True is true, the value is 885 views
# saving video to file...
# https://www.youtube.com/watch?v=6lbih4NhajI
# 5.6K views
# True is true, the value is 5.6K views
# saving video to file...
# https://www.youtube.com/shorts/Usgrs9kH_x0
# wrote video links to visited_links.txt file
# https://www.youtube.com/watch?v=-NljKEbEEZ8
#
# not empty line
# https://www.youtube.com/watch?v=l_NQ2ZFE_sw
#
# not empty line
# https://www.youtube.com/watch?v=HphvCslECxs
#
# not empty line
# https://www.youtube.com/watch?v=twvgHVlus6c
#
# not empty line
# https://www.youtube.com/watch?v=4LsR637gWVo
#
# not empty line
# https://www.youtube.com/watch?v=WN1C4_SciYI
#
# not empty line
# https://www.youtube.com/watch?v=3PXUO_7Pj5o
#
# not empty line
# https://www.youtube.com/watch?v=TzQW1eQr82E
#
# not empty line
# https://www.youtube.com/watch?v=e__OqNA0zhw
#
# not empty line
# https://www.youtube.com/watch?v=oky3D0-JdsQ
#
# not empty line
# https://www.youtube.com/watch?v=LqqHWJiYZro
#
# not empty line
# https://www.youtube.com/watch?v=NuT0BbzeJ38
#
# not empty line
# https://www.youtube.com/watch?v=-NljKEbEEZ8
#
# not empty line
# https://www.youtube.com/watch?v=l_NQ2ZFE_sw
#
# not empty line
# https://www.youtube.com/watch?v=HphvCslECxs
#
# not empty line
# https://www.youtube.com/watch?v=twvgHVlus6c
#
# not empty line
# https://www.youtube.com/watch?v=4LsR637gWVo
#
# not empty line
# https://www.youtube.com/watch?v=WN1C4_SciYI
#
# not empty line
# https://www.youtube.com/watch?v=3PXUO_7Pj5o
#
# not empty line
# https://www.youtube.com/watch?v=TzQW1eQr82E
#
# not empty line
# https://www.youtube.com/watch?v=e__OqNA0zhw
#
# not empty line
# https://www.youtube.com/watch?v=oky3D0-JdsQ
#
# not empty line
# https://www.youtube.com/watch?v=LqqHWJiYZro
#
# not empty line
# https://www.youtube.com/watch?v=NuT0BbzeJ38
#
# not empty line
# https://www.youtube.com/watch?v=7Hc8yzzkloc
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 0
# vid counter is: 1
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=7Hc8yzzkloc
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=FjQ1FSTsE6A
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 1
# vid counter is: 2
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=FjQ1FSTsE6A
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=JepJ_jyzUV8
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 2
# vid counter is: 3
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=JepJ_jyzUV8
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=M0HaYAA_M80
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 3
# vid counter is: 4
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=M0HaYAA_M80
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=GwOSDSjJlnA
#
# not empty line
# https://www.youtube.com/watch?v=uu9VQNXoNRk
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 4
# vid counter is: 5
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=uu9VQNXoNRk
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=z1aCn-8OGrk
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 5
# vid counter is: 6
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=z1aCn-8OGrk
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=Z0iME4eTAEY
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 6
# vid counter is: 7
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=Z0iME4eTAEY
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=CMORghwqwwc
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 7
# vid counter is: 8
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=CMORghwqwwc
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=vWojD9OiG38
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 8
# vid counter is: 9
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=vWojD9OiG38
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=bKZPKNPtNh4
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 9
# vid counter is: 10
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=bKZPKNPtNh4
#
# ___opened video in new tab
# should of went down now a bit
# This video has comment section disabled, going back...
# https://www.youtube.com/shorts/05HfVCu09PQ
#
# not empty line
# https://www.youtube.com/watch?v=xmkr9pB1Bag
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 9
# vid counter is: 11
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=xmkr9pB1Bag
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=sKxzLS1FaXQ
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 10
# vid counter is: 12
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=sKxzLS1FaXQ
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=wQiO0xJWlOo
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 11
# vid counter is: 13
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=wQiO0xJWlOo
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=E4zhCTAw5bc
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 12
# vid counter is: 14
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=E4zhCTAw5bc
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=rNP6NiW0d3w
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 13
# vid counter is: 15
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=rNP6NiW0d3w
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/shorts/oYcG8kBQKMg
#
# not empty line
# https://www.youtube.com/watch?v=bqe3wsv9MxE
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 14
# vid counter is: 16
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=bqe3wsv9MxE
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/shorts/CDYdN8wEmt8
#
# not empty line
# https://www.youtube.com/watch?v=NXFzMGJSP6w
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 15
# vid counter is: 17
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=NXFzMGJSP6w
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=NNpVC121HEg
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 16
# vid counter is: 18
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=NNpVC121HEg
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=8qRQR2u7KCM
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 17
# vid counter is: 19
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=8qRQR2u7KCM
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=oQoUys2aduE
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 18
# vid counter is: 20
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=oQoUys2aduE
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=i0PGQOWpcdE
#
# not empty line
# wrote video link to txt file
# nothing happened with file too large updater
# comments counter is 19
# vid counter is: 21
# videocacat________________________
# going to video...
# link for video is: https://www.youtube.com/watch?v=i0PGQOWpcdE
#
# ___opened video in new tab
# should of went down now a bit
# Comment section has been found.
# comment found:  0
# found the title :), page is loaded
# clicked textbox
# writing to textbox...
# pasted comment, now waiting 1 second...
# finished writing to textbox, now going back one page after 3 seconds...
# https://www.youtube.com/watch?v=MZSLfRnwcSs
#
# not empty line
# We reached 20 comments. Stopping script. Goodbye!

# %%
print('____________REACHED END OF PROGRAM')
sleep(999999)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8116\2355608072.py in <module>
#       1 # # Step 03: accept terms and rights
# ----> 2 accept_conditions()
#       3 # # Step 04: Sign in
#       4 sign_in()
#       5 # Step 05: Search
#
# ~\AppData\Local\Temp\ipykernel_8116\3775382094.py in accept_conditions()
#       1 # Functions
#       2 def accept_conditions():
# ----> 3     accept_all_conditions_01 = driver.find_element(By.XPATH,
#       4                                                    '//*[@id="yDmH0d"]/c-wiz/div/div/div/div[2]/div[1]/div[3]/div[1]/form[2]/div/div/button')
#       5     if accept_all_conditions_01:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     854             value = '[name="%s"]' % value
#     855
# --> 856         return self.execute(Command.FIND_ELEMENT, {
#     857             'using': by,
#     858             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     427         response = self.command_executor.execute(driver_command, params)
#     428         if response:
# --> 429             self.error_handler.check_response(response)
#     430             response['value'] = self._unwrap_value(
#     431                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="yDmH0d"]/c-wiz/div/div/div/div[2]/div[1]/div[3]/div[1]/form[2]/div/div/button"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010FACD3+2075859]
# 	Ordinal0 [0x0108EE61+1633889]
# 	Ordinal0 [0x00F8B7BD+571325]
# 	Ordinal0 [0x00FBAC2F+764975]
# 	Ordinal0 [0x00FBAE1B+765467]
# 	Ordinal0 [0x00FED0F2+970994]
# 	Ordinal0 [0x00FD7364+881508]
# 	Ordinal0 [0x00FEB56A+963946]
# 	Ordinal0 [0x00FD7136+880950]
# 	Ordinal0 [0x00FAFEFD+720637]
# 	Ordinal0 [0x00FB0F3F+724799]
# 	GetHandleVerifier [0x013AEED2+2769538]
# 	GetHandleVerifier [0x013A0D95+2711877]
# 	GetHandleVerifier [0x0118A03A+521194]
# 	GetHandleVerifier [0x01188DA0+516432]
# 	Ordinal0 [0x0109682C+1665068]
# 	Ordinal0 [0x0109B128+1683752]
# 	Ordinal0 [0x0109B215+1683989]
# 	Ordinal0 [0x010A6484+1729668]
# 	BaseThreadInitThunk [0x767AFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7B8E+238]

# %%
sleep(999999)

# %%
# Out:
# False

# %% [markdown]
# # Step 01: Chrome Driver Setup

# %% [markdown]
# # Step 02: Inputs Setup

# %% [markdown]
# # Step 03: accept terms and rights

# %%
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36328\2959158449.py in <module>
# ----> 1 accept_all_conditions_01 = driver.find_element(By.XPATH,
#       2                                                '//*[@id="yDmH0d"]/c-wiz/div/div/div/div[2]/div[1]/div[3]/div[1]/form[2]/div/div/button')
#       3 if accept_all_conditions_01:
#       4     accept_all_conditions_01.click()
#       5
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     854             value = '[name="%s"]' % value
#     855
# --> 856         return self.execute(Command.FIND_ELEMENT, {
#     857             'using': by,
#     858             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     427         response = self.command_executor.execute(driver_command, params)
#     428         if response:
# --> 429             self.error_handler.check_response(response)
#     430             response['value'] = self._unwrap_value(
#     431                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="yDmH0d"]/c-wiz/div/div/div/div[2]/div[1]/div[3]/div[1]/form[2]/div/div/button"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F9ACD3+2075859]
# 	Ordinal0 [0x00F2EE61+1633889]
# 	Ordinal0 [0x00E2B7BD+571325]
# 	Ordinal0 [0x00E5AC2F+764975]
# 	Ordinal0 [0x00E5AE1B+765467]
# 	Ordinal0 [0x00E8D0F2+970994]
# 	Ordinal0 [0x00E77364+881508]
# 	Ordinal0 [0x00E8B56A+963946]
# 	Ordinal0 [0x00E77136+880950]
# 	Ordinal0 [0x00E4FEFD+720637]
# 	Ordinal0 [0x00E50F3F+724799]
# 	GetHandleVerifier [0x0124EED2+2769538]
# 	GetHandleVerifier [0x01240D95+2711877]
# 	GetHandleVerifier [0x0102A03A+521194]
# 	GetHandleVerifier [0x01028DA0+516432]
# 	Ordinal0 [0x00F3682C+1665068]
# 	Ordinal0 [0x00F3B128+1683752]
# 	Ordinal0 [0x00F3B215+1683989]
# 	Ordinal0 [0x00F46484+1729668]
# 	BaseThreadInitThunk [0x767AFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7B8E+238]

# %% [markdown]
# # Step 04: Sign in

# %%
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36328\2172140563.py in <module>
# ----> 1 sign_in_input_form = driver.find_element(By.XPATH, '//*[@id="identifierId"]')
#       2 sign_in_input_form.send_keys(username)
#       3
#       4 next_button_01 = driver.find_element(By.XPATH, '//*[@id="identifierNext"]/div/button')
#       5 next_button_01.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     854             value = '[name="%s"]' % value
#     855
# --> 856         return self.execute(Command.FIND_ELEMENT, {
#     857             'using': by,
#     858             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     427         response = self.command_executor.execute(driver_command, params)
#     428         if response:
# --> 429             self.error_handler.check_response(response)
#     430             response['value'] = self._unwrap_value(
#     431                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="identifierId"]"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F9ACD3+2075859]
# 	Ordinal0 [0x00F2EE61+1633889]
# 	Ordinal0 [0x00E2B7BD+571325]
# 	Ordinal0 [0x00E5AC2F+764975]
# 	Ordinal0 [0x00E5AE1B+765467]
# 	Ordinal0 [0x00E8D0F2+970994]
# 	Ordinal0 [0x00E77364+881508]
# 	Ordinal0 [0x00E8B56A+963946]
# 	Ordinal0 [0x00E77136+880950]
# 	Ordinal0 [0x00E4FEFD+720637]
# 	Ordinal0 [0x00E50F3F+724799]
# 	GetHandleVerifier [0x0124EED2+2769538]
# 	GetHandleVerifier [0x01240D95+2711877]
# 	GetHandleVerifier [0x0102A03A+521194]
# 	GetHandleVerifier [0x01028DA0+516432]
# 	Ordinal0 [0x00F3682C+1665068]
# 	Ordinal0 [0x00F3B128+1683752]
# 	Ordinal0 [0x00F3B215+1683989]
# 	Ordinal0 [0x00F46484+1729668]
# 	BaseThreadInitThunk [0x767AFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772D7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x772D7B8E+238]
